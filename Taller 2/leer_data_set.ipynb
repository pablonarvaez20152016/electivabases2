# %%
import pandas as pd

# %%
data=pd.read_csv('./Saber_pro.csv', sep=';')

# %%
data.head(10)
# Out:
#              nota genero  estu_edad_examen estado_civil  \
# 0   BAJO LA MEDIA      M                24   SOLTERO(A)
# 1  SOBRE LA MEDIA      F                23   SOLTERO(A)
# 2   BAJO LA MEDIA      M                30   SOLTERO(A)
# 3   BAJO LA MEDIA      F                20   SOLTERO(A)
# 4   BAJO LA MEDIA      M                34   SOLTERO(A)
# 5  SOBRE LA MEDIA      M                25   SOLTERO(A)
# 6  SOBRE LA MEDIA      F                24  UNION LIBRE
# 7  SOBRE LA MEDIA      M                22   SOLTERO(A)
# 8  SOBRE LA MEDIA      F                21   SOLTERO(A)
# 9   BAJO LA MEDIA      F                23   SOLTERO(A)
#
#                                  estu_hogar_actual estu_sn_cabeza_fmlia  \
# 0                      ES EL HABITUAL - PERMANENTE                   NO
# 1                      ES EL HABITUAL - PERMANENTE                   NO
# 2                      ES EL HABITUAL - PERMANENTE                   SI
# ...

# %%
data.dtypes
# Out:
# nota                            object
# genero                          object
# estu_edad_examen               float64
# estado_civil                    object
# estu_hogar_actual               object
# estu_sn_cabeza_fmlia            object
# estu_pers_cargo                 object
# fami_nivel_educa_padres         object
# fami_ocup_padre                 object
# fami_ocup_madre                 object
# inst_tipo                       object
# inst_caracter_academico         object
# inst_acreditada                 object
# prog_acreditado                 object
# inst_programa_zona              object
# estu_metodo_prgm                object
# estu_area_conoc                 object
# area_grupo_referencia           object
# estu_pje_creditos               object
# estu_titulo_bto                 object
# estu_financiacion_matricula     object
# estu_estrato                    object
# fami_nivel_sisben               object
# econ_condicion_vivienda         object
# ...

# %%
df_dummies=pd.get_dummies(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/lib/python3/dist-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#    2189                 result = np.empty(len(values), dtype=object)
# -> 2190                 result[:] = values
#    2191             except ValueError:
#
# ValueError: could not broadcast input array from shape (77649,32) into shape (77649)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-9598b6081423> in <module>()
# ----> 1 df_dummies=pd.get_dummies(data)
#
# /usr/lib/python3/dist-packages/pandas/core/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na)
#     999     """
#    1000     # Series avoids inconsistent NaN handling
# -> 1001     cat = Categorical.from_array(Series(data))
# ...
